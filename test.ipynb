# %%
import pyspark
from pyspark import SQLContext
from pyspark.sql import SparkSession
spark = SparkSession.builder.config("spark.driver.host","localhost").appName("testing").getOrCreate()
conf = pyspark.SparkConf()
spark_context = SparkSession.builder.config(conf=conf).getOrCreate()
from pyspark.sql import functions as F
from pyspark.sql.window import Window

# %%
claims = spark.read.options(header=True).csv(r"C:\Users\kring\test\DE1_0_2008_to_2010_Outpatient_Claims_Sample_20.csv")

# %%
summary = spark.read.options(header=True).csv(r"C:\Users\kring\test\DE1_0_2009_Beneficiary_Summary_File_Sample_20.csv")

# %%
# Convert chronic illness cols to single, concatenating multiple diagnoses

# %%
diagnoses_cols = ["SP_ALZHDMTA", "SP_CHF", "SP_CHRNKIDN", "SP_CNCR", "SP_COPD", "SP_DEPRESSN", "SP_DIABETES", "SP_ISCHMCHT", "SP_OSTEOPRS", "SP_RA_OA", "SP_STRKETIA"]

# %%
new_summary = summary

# %%
for column in new_summary.columns:
    if column in diagnoses_cols:
        new_summary = new_summary.withColumn(column, F.when(new_summary[column] == "2", "0").otherwise(new_summary[column]))

# %%
new_summary = new_summary.withColumn("Conditions_Total", F.expr("+".join(diagnoses_cols)))

# %%
new_summary.show(5, truncate=False, vertical=True)
# Out:
# -RECORD 0------------------------------------
#  DESYNPUF_ID              | 000002F7E0A96C32
#  BENE_BIRTH_DT            | 19190701
#  BENE_DEATH_DT            | NULL
#  BENE_SEX_IDENT_CD        | 2
#  BENE_RACE_CD             | 2
#  BENE_ESRD_IND            | 0
#  SP_STATE_CODE            | 05
#  BENE_COUNTY_CD           | 400
#  BENE_HI_CVRAGE_TOT_MONS  | 0
#  BENE_SMI_CVRAGE_TOT_MONS | 0
#  BENE_HMO_CVRAGE_TOT_MONS | 0
#  PLAN_CVRG_MOS_NUM        | 00
#  SP_ALZHDMTA              | 0
#  SP_CHF                   | 0
#  SP_CHRNKIDN              | 0
#  SP_CNCR                  | 0
#  SP_COPD                  | 0
#  SP_DEPRESSN              | 0
#  SP_DIABETES              | 0
#  SP_ISCHMCHT              | 0
#  SP_OSTEOPRS              | 0
#  SP_RA_OA                 | 0
#  SP_STRKETIA              | 0
#  MEDREIMB_IP              | 0.00
#  BENRES_IP                | 0.00
#  PPPYMT_IP                | 0.00
#  MEDREIMB_OP              | 0.00
#  BENRES_OP                | 0.00
#  PPPYMT_OP                | 0.00
#  MEDREIMB_CAR             | 0.00
#  BENRES_CAR               | 0.00
#  PPPYMT_CAR               | 0.00
#  Conditions_Total         | 0.0
# -RECORD 1------------------------------------
#  DESYNPUF_ID              | 00001C24EE7B06AC
#  BENE_BIRTH_DT            | 19360501
#  BENE_DEATH_DT            | NULL
#  BENE_SEX_IDENT_CD        | 1
#  BENE_RACE_CD             | 1
#  BENE_ESRD_IND            | 0
#  SP_STATE_CODE            | 11
#  BENE_COUNTY_CD           | 530
#  BENE_HI_CVRAGE_TOT_MONS  | 12
#  BENE_SMI_CVRAGE_TOT_MONS | 12
#  BENE_HMO_CVRAGE_TOT_MONS | 0
#  PLAN_CVRG_MOS_NUM        | 12
#  SP_ALZHDMTA              | 0
#  SP_CHF                   | 0
#  SP_CHRNKIDN              | 0
#  SP_CNCR                  | 0
#  SP_COPD                  | 0
#  SP_DEPRESSN              | 0
#  SP_DIABETES              | 0
#  SP_ISCHMCHT              | 1
#  SP_OSTEOPRS              | 0
#  SP_RA_OA                 | 0
#  SP_STRKETIA              | 0
#  MEDREIMB_IP              | 0.00
#  BENRES_IP                | 0.00
#  PPPYMT_IP                | 0.00
#  MEDREIMB_OP              | 200.00
#  BENRES_OP                | 40.00
#  PPPYMT_OP                | 0.00
#  MEDREIMB_CAR             | 800.00
#  BENRES_CAR               | 260.00
#  PPPYMT_CAR               | 0.00
#  Conditions_Total         | 1.0
# -RECORD 2------------------------------------
#  DESYNPUF_ID              | 000072CF62193213
#  BENE_BIRTH_DT            | 19310401
#  BENE_DEATH_DT            | NULL
#  BENE_SEX_IDENT_CD        | 2
#  BENE_RACE_CD             | 1
#  BENE_ESRD_IND            | 0
#  SP_STATE_CODE            | 34
#  BENE_COUNTY_CD           | 120
#  BENE_HI_CVRAGE_TOT_MONS  | 12
#  BENE_SMI_CVRAGE_TOT_MONS | 12
#  BENE_HMO_CVRAGE_TOT_MONS | 0
#  PLAN_CVRG_MOS_NUM        | 12
#  SP_ALZHDMTA              | 0
#  SP_CHF                   | 0
#  SP_CHRNKIDN              | 0
#  SP_CNCR                  | 0
#  SP_COPD                  | 0
#  SP_DEPRESSN              | 0
#  SP_DIABETES              | 0
#  SP_ISCHMCHT              | 0
#  SP_OSTEOPRS              | 0
#  SP_RA_OA                 | 0
#  SP_STRKETIA              | 0
#  MEDREIMB_IP              | 0.00
#  BENRES_IP                | 0.00
#  PPPYMT_IP                | 0.00
#  MEDREIMB_OP              | 130.00
#  BENRES_OP                | 70.00
#  PPPYMT_OP                | 0.00
#  MEDREIMB_CAR             | 440.00
#  BENRES_CAR               | 30.00
#  PPPYMT_CAR               | 50.00
#  Conditions_Total         | 0.0
# -RECORD 3------------------------------------
#  DESYNPUF_ID              | 0000DCD33779ED8A
#  BENE_BIRTH_DT            | 19420501
#  BENE_DEATH_DT            | NULL
#  BENE_SEX_IDENT_CD        | 2
#  BENE_RACE_CD             | 2
#  BENE_ESRD_IND            | 0
#  SP_STATE_CODE            | 11
#  BENE_COUNTY_CD           | 190
#  BENE_HI_CVRAGE_TOT_MONS  | 12
#  BENE_SMI_CVRAGE_TOT_MONS | 12
#  BENE_HMO_CVRAGE_TOT_MONS | 0
#  PLAN_CVRG_MOS_NUM        | 12
#  SP_ALZHDMTA              | 1
#  SP_CHF                   | 1
#  SP_CHRNKIDN              | 0
#  SP_CNCR                  | 1
#  SP_COPD                  | 0
#  SP_DEPRESSN              | 0
#  SP_DIABETES              | 0
#  SP_ISCHMCHT              | 0
#  SP_OSTEOPRS              | 0
#  SP_RA_OA                 | 0
#  SP_STRKETIA              | 0
#  MEDREIMB_IP              | 0.00
#  BENRES_IP                | 0.00
#  PPPYMT_IP                | 0.00
#  MEDREIMB_OP              | 90.00
#  BENRES_OP                | 20.00
#  PPPYMT_OP                | 0.00
#  MEDREIMB_CAR             | 930.00
#  BENRES_CAR               | 200.00
#  PPPYMT_CAR               | 0.00
#  Conditions_Total         | 3.0
# -RECORD 4------------------------------------
#  DESYNPUF_ID              | 0000F1EB530967F3
#  BENE_BIRTH_DT            | 19350401
#  BENE_DEATH_DT            | NULL
#  BENE_SEX_IDENT_CD        | 2
#  BENE_RACE_CD             | 1
#  BENE_ESRD_IND            | 0
#  SP_STATE_CODE            | 23
#  BENE_COUNTY_CD           | 720
#  BENE_HI_CVRAGE_TOT_MONS  | 12
#  BENE_SMI_CVRAGE_TOT_MONS | 12
#  BENE_HMO_CVRAGE_TOT_MONS | 0
#  PLAN_CVRG_MOS_NUM        | 12
#  SP_ALZHDMTA              | 1
#  SP_CHF                   | 1
#  SP_CHRNKIDN              | 0
#  SP_CNCR                  | 1
#  SP_COPD                  | 0
#  SP_DEPRESSN              | 1
#  SP_DIABETES              | 1
#  SP_ISCHMCHT              | 1
#  SP_OSTEOPRS              | 1
#  SP_RA_OA                 | 1
#  SP_STRKETIA              | 0
#  MEDREIMB_IP              | 0.00
#  BENRES_IP                | 0.00
#  PPPYMT_IP                | 0.00
#  MEDREIMB_OP              | 70.00
#  BENRES_OP                | 200.00
#  PPPYMT_OP                | 0.00
#  MEDREIMB_CAR             | 4950.00
#  BENRES_CAR               | 1340.00
#  PPPYMT_CAR               | 0.00
#  Conditions_Total         | 8.0
# only showing top 5 rows

# %%
# If a member has 3 or more diagnoses, categorize as multiple

# %%
new_summary = new_summary.withColumn("Conditions_Total", F.when(F.col("Conditions_Total") >= 3, "Multiple").otherwise(F.col("Conditions_Total")))

# %%
new_summary.show(5, truncate=False, vertical=True)
# Out:
# -RECORD 0------------------------------------
#  DESYNPUF_ID              | 000002F7E0A96C32
#  BENE_BIRTH_DT            | 19190701
#  BENE_DEATH_DT            | NULL
#  BENE_SEX_IDENT_CD        | 2
#  BENE_RACE_CD             | 2
#  BENE_ESRD_IND            | 0
#  SP_STATE_CODE            | 05
#  BENE_COUNTY_CD           | 400
#  BENE_HI_CVRAGE_TOT_MONS  | 0
#  BENE_SMI_CVRAGE_TOT_MONS | 0
#  BENE_HMO_CVRAGE_TOT_MONS | 0
#  PLAN_CVRG_MOS_NUM        | 00
#  SP_ALZHDMTA              | 0
#  SP_CHF                   | 0
#  SP_CHRNKIDN              | 0
#  SP_CNCR                  | 0
#  SP_COPD                  | 0
#  SP_DEPRESSN              | 0
#  SP_DIABETES              | 0
#  SP_ISCHMCHT              | 0
#  SP_OSTEOPRS              | 0
#  SP_RA_OA                 | 0
#  SP_STRKETIA              | 0
#  MEDREIMB_IP              | 0.00
#  BENRES_IP                | 0.00
#  PPPYMT_IP                | 0.00
#  MEDREIMB_OP              | 0.00
#  BENRES_OP                | 0.00
#  PPPYMT_OP                | 0.00
#  MEDREIMB_CAR             | 0.00
#  BENRES_CAR               | 0.00
#  PPPYMT_CAR               | 0.00
#  Conditions_Total         | 0.0
# -RECORD 1------------------------------------
#  DESYNPUF_ID              | 00001C24EE7B06AC
#  BENE_BIRTH_DT            | 19360501
#  BENE_DEATH_DT            | NULL
#  BENE_SEX_IDENT_CD        | 1
#  BENE_RACE_CD             | 1
#  BENE_ESRD_IND            | 0
#  SP_STATE_CODE            | 11
#  BENE_COUNTY_CD           | 530
#  BENE_HI_CVRAGE_TOT_MONS  | 12
#  BENE_SMI_CVRAGE_TOT_MONS | 12
#  BENE_HMO_CVRAGE_TOT_MONS | 0
#  PLAN_CVRG_MOS_NUM        | 12
#  SP_ALZHDMTA              | 0
#  SP_CHF                   | 0
#  SP_CHRNKIDN              | 0
#  SP_CNCR                  | 0
#  SP_COPD                  | 0
#  SP_DEPRESSN              | 0
#  SP_DIABETES              | 0
#  SP_ISCHMCHT              | 1
#  SP_OSTEOPRS              | 0
#  SP_RA_OA                 | 0
#  SP_STRKETIA              | 0
#  MEDREIMB_IP              | 0.00
#  BENRES_IP                | 0.00
#  PPPYMT_IP                | 0.00
#  MEDREIMB_OP              | 200.00
#  BENRES_OP                | 40.00
#  PPPYMT_OP                | 0.00
#  MEDREIMB_CAR             | 800.00
#  BENRES_CAR               | 260.00
#  PPPYMT_CAR               | 0.00
#  Conditions_Total         | 1.0
# -RECORD 2------------------------------------
#  DESYNPUF_ID              | 000072CF62193213
#  BENE_BIRTH_DT            | 19310401
#  BENE_DEATH_DT            | NULL
#  BENE_SEX_IDENT_CD        | 2
#  BENE_RACE_CD             | 1
#  BENE_ESRD_IND            | 0
#  SP_STATE_CODE            | 34
#  BENE_COUNTY_CD           | 120
#  BENE_HI_CVRAGE_TOT_MONS  | 12
#  BENE_SMI_CVRAGE_TOT_MONS | 12
#  BENE_HMO_CVRAGE_TOT_MONS | 0
#  PLAN_CVRG_MOS_NUM        | 12
#  SP_ALZHDMTA              | 0
#  SP_CHF                   | 0
#  SP_CHRNKIDN              | 0
#  SP_CNCR                  | 0
#  SP_COPD                  | 0
#  SP_DEPRESSN              | 0
#  SP_DIABETES              | 0
#  SP_ISCHMCHT              | 0
#  SP_OSTEOPRS              | 0
#  SP_RA_OA                 | 0
#  SP_STRKETIA              | 0
#  MEDREIMB_IP              | 0.00
#  BENRES_IP                | 0.00
#  PPPYMT_IP                | 0.00
#  MEDREIMB_OP              | 130.00
#  BENRES_OP                | 70.00
#  PPPYMT_OP                | 0.00
#  MEDREIMB_CAR             | 440.00
#  BENRES_CAR               | 30.00
#  PPPYMT_CAR               | 50.00
#  Conditions_Total         | 0.0
# -RECORD 3------------------------------------
#  DESYNPUF_ID              | 0000DCD33779ED8A
#  BENE_BIRTH_DT            | 19420501
#  BENE_DEATH_DT            | NULL
#  BENE_SEX_IDENT_CD        | 2
#  BENE_RACE_CD             | 2
#  BENE_ESRD_IND            | 0
#  SP_STATE_CODE            | 11
#  BENE_COUNTY_CD           | 190
#  BENE_HI_CVRAGE_TOT_MONS  | 12
#  BENE_SMI_CVRAGE_TOT_MONS | 12
#  BENE_HMO_CVRAGE_TOT_MONS | 0
#  PLAN_CVRG_MOS_NUM        | 12
#  SP_ALZHDMTA              | 1
#  SP_CHF                   | 1
#  SP_CHRNKIDN              | 0
#  SP_CNCR                  | 1
#  SP_COPD                  | 0
#  SP_DEPRESSN              | 0
#  SP_DIABETES              | 0
#  SP_ISCHMCHT              | 0
#  SP_OSTEOPRS              | 0
#  SP_RA_OA                 | 0
#  SP_STRKETIA              | 0
#  MEDREIMB_IP              | 0.00
#  BENRES_IP                | 0.00
#  PPPYMT_IP                | 0.00
#  MEDREIMB_OP              | 90.00
#  BENRES_OP                | 20.00
#  PPPYMT_OP                | 0.00
#  MEDREIMB_CAR             | 930.00
#  BENRES_CAR               | 200.00
#  PPPYMT_CAR               | 0.00
#  Conditions_Total         | Multiple
# -RECORD 4------------------------------------
#  DESYNPUF_ID              | 0000F1EB530967F3
#  BENE_BIRTH_DT            | 19350401
#  BENE_DEATH_DT            | NULL
#  BENE_SEX_IDENT_CD        | 2
#  BENE_RACE_CD             | 1
#  BENE_ESRD_IND            | 0
#  SP_STATE_CODE            | 23
#  BENE_COUNTY_CD           | 720
#  BENE_HI_CVRAGE_TOT_MONS  | 12
#  BENE_SMI_CVRAGE_TOT_MONS | 12
#  BENE_HMO_CVRAGE_TOT_MONS | 0
#  PLAN_CVRG_MOS_NUM        | 12
#  SP_ALZHDMTA              | 1
#  SP_CHF                   | 1
#  SP_CHRNKIDN              | 0
#  SP_CNCR                  | 1
#  SP_COPD                  | 0
#  SP_DEPRESSN              | 1
#  SP_DIABETES              | 1
#  SP_ISCHMCHT              | 1
#  SP_OSTEOPRS              | 1
#  SP_RA_OA                 | 1
#  SP_STRKETIA              | 0
#  MEDREIMB_IP              | 0.00
#  BENRES_IP                | 0.00
#  PPPYMT_IP                | 0.00
#  MEDREIMB_OP              | 70.00
#  BENRES_OP                | 200.00
#  PPPYMT_OP                | 0.00
#  MEDREIMB_CAR             | 4950.00
#  BENRES_CAR               | 1340.00
#  PPPYMT_CAR               | 0.00
#  Conditions_Total         | Multiple
# only showing top 5 rows

# %%
# Join claims and benefit data

# %%
joined = new_summary.join(claims, "DESYNPUF_ID", "full")

# %%
joined.show(5, truncate=False, vertical=True)
# Out:
# -RECORD 0------------------------------------------
#  DESYNPUF_ID                    | 00028CFDA8612B87
#  BENE_BIRTH_DT                  | 19431001
#  BENE_DEATH_DT                  | NULL
#  BENE_SEX_IDENT_CD              | 2
#  BENE_RACE_CD                   | 1
#  BENE_ESRD_IND                  | 0
#  SP_STATE_CODE                  | 14
#  BENE_COUNTY_CD                 | 740
#  BENE_HI_CVRAGE_TOT_MONS        | 12
#  BENE_SMI_CVRAGE_TOT_MONS       | 12
#  BENE_HMO_CVRAGE_TOT_MONS       | 0
#  PLAN_CVRG_MOS_NUM              | 00
#  SP_ALZHDMTA                    | 0
#  SP_CHF                         | 0
#  SP_CHRNKIDN                    | 0
#  SP_CNCR                        | 0
#  SP_COPD                        | 0
#  SP_DEPRESSN                    | 1
#  SP_DIABETES                    | 1
#  SP_ISCHMCHT                    | 1
#  SP_OSTEOPRS                    | 0
#  SP_RA_OA                       | 0
#  SP_STRKETIA                    | 0
#  MEDREIMB_IP                    | 0.00
#  BENRES_IP                      | 0.00
#  PPPYMT_IP                      | 0.00
#  MEDREIMB_OP                    | 1300.00
#  BENRES_OP                      | 110.00
#  PPPYMT_OP                      | 0.00
#  MEDREIMB_CAR                   | 1600.00
#  BENRES_CAR                     | 410.00
#  PPPYMT_CAR                     | 0.00
#  Conditions_Total               | Multiple
#  CLM_ID                         | 684682269601440
#  SEGMENT                        | 1
#  CLM_FROM_DT                    | 20090520
#  CLM_THRU_DT                    | 20090520
#  PRVDR_NUM                      | 1400JU
#  CLM_PMT_AMT                    | 400.00
#  NCH_PRMRY_PYR_CLM_PD_AMT       | 0.00
#  AT_PHYSN_NPI                   | 4684916159
#  OP_PHYSN_NPI                   | NULL
#  OT_PHYSN_NPI                   | 4684916159
#  NCH_BENE_BLOOD_DDCTBL_LBLTY_AM | 0.00
#  ICD9_DGNS_CD_1                 | 4142
#  ICD9_DGNS_CD_2                 | V641
#  ICD9_DGNS_CD_3                 | 25000
#  ICD9_DGNS_CD_4                 | 78650
#  ICD9_DGNS_CD_5                 | V4581
#  ICD9_DGNS_CD_6                 | NULL
#  ICD9_DGNS_CD_7                 | NULL
#  ICD9_DGNS_CD_8                 | NULL
#  ICD9_DGNS_CD_9                 | NULL
#  ICD9_DGNS_CD_10                | NULL
#  ICD9_PRCDR_CD_1                | NULL
#  ICD9_PRCDR_CD_2                | NULL
#  ICD9_PRCDR_CD_3                | NULL
#  ICD9_PRCDR_CD_4                | NULL
#  ICD9_PRCDR_CD_5                | NULL
#  ICD9_PRCDR_CD_6                | NULL
#  NCH_BENE_PTB_DDCTBL_AMT        | 0.00
#  NCH_BENE_PTB_COINSRNC_AMT      | 100.00
#  ADMTNG_ICD9_DGNS_CD            | NULL
#  HCPCS_CD_1                     | NULL
#  HCPCS_CD_2                     | NULL
#  HCPCS_CD_3                     | NULL
#  HCPCS_CD_4                     | 83690
#  HCPCS_CD_5                     | 84484
#  HCPCS_CD_6                     | 99285
#  HCPCS_CD_7                     | P9040
#  HCPCS_CD_8                     | 85025
#  HCPCS_CD_9                     | 96375
#  HCPCS_CD_10                    | 80053
#  HCPCS_CD_11                    | 85027
#  HCPCS_CD_12                    | 71250
#  HCPCS_CD_13                    | Q9967
#  HCPCS_CD_14                    | 85025
#  HCPCS_CD_15                    | 78480
#  HCPCS_CD_16                    | NULL
#  HCPCS_CD_17                    | NULL
#  HCPCS_CD_18                    | NULL
#  HCPCS_CD_19                    | NULL
#  HCPCS_CD_20                    | NULL
#  HCPCS_CD_21                    | NULL
#  HCPCS_CD_22                    | NULL
#  HCPCS_CD_23                    | NULL
#  HCPCS_CD_24                    | NULL
#  HCPCS_CD_25                    | NULL
#  HCPCS_CD_26                    | NULL
#  HCPCS_CD_27                    | NULL
#  HCPCS_CD_28                    | NULL
#  HCPCS_CD_29                    | NULL
#  HCPCS_CD_30                    | NULL
#  HCPCS_CD_31                    | NULL
#  HCPCS_CD_32                    | NULL
#  HCPCS_CD_33                    | NULL
#  HCPCS_CD_34                    | NULL
#  HCPCS_CD_35                    | NULL
#  HCPCS_CD_36                    | NULL
#  HCPCS_CD_37                    | NULL
#  HCPCS_CD_38                    | NULL
#  HCPCS_CD_39                    | NULL
#  HCPCS_CD_40                    | NULL
#  HCPCS_CD_41                    | NULL
#  HCPCS_CD_42                    | NULL
#  HCPCS_CD_43                    | NULL
#  HCPCS_CD_44                    | NULL
#  HCPCS_CD_45                    | NULL
# -RECORD 1------------------------------------------
#  DESYNPUF_ID                    | 00028CFDA8612B87
#  BENE_BIRTH_DT                  | 19431001
#  BENE_DEATH_DT                  | NULL
#  BENE_SEX_IDENT_CD              | 2
#  BENE_RACE_CD                   | 1
#  BENE_ESRD_IND                  | 0
#  SP_STATE_CODE                  | 14
#  BENE_COUNTY_CD                 | 740
#  BENE_HI_CVRAGE_TOT_MONS        | 12
#  BENE_SMI_CVRAGE_TOT_MONS       | 12
#  BENE_HMO_CVRAGE_TOT_MONS       | 0
#  PLAN_CVRG_MOS_NUM              | 00
#  SP_ALZHDMTA                    | 0
#  SP_CHF                         | 0
#  SP_CHRNKIDN                    | 0
#  SP_CNCR                        | 0
#  SP_COPD                        | 0
#  SP_DEPRESSN                    | 1
#  SP_DIABETES                    | 1
#  SP_ISCHMCHT                    | 1
#  SP_OSTEOPRS                    | 0
#  SP_RA_OA                       | 0
#  SP_STRKETIA                    | 0
#  MEDREIMB_IP                    | 0.00
#  BENRES_IP                      | 0.00
#  PPPYMT_IP                      | 0.00
#  MEDREIMB_OP                    | 1300.00
#  BENRES_OP                      | 110.00
#  PPPYMT_OP                      | 0.00
#  MEDREIMB_CAR                   | 1600.00
#  BENRES_CAR                     | 410.00
#  PPPYMT_CAR                     | 0.00
#  Conditions_Total               | Multiple
#  CLM_ID                         | 684082269444555
#  SEGMENT                        | 1
#  CLM_FROM_DT                    | 20090916
#  CLM_THRU_DT                    | 20090916
#  PRVDR_NUM                      | 2400DG
#  CLM_PMT_AMT                    | 200.00
#  NCH_PRMRY_PYR_CLM_PD_AMT       | 0.00
#  AT_PHYSN_NPI                   | 3875147506
#  OP_PHYSN_NPI                   | 1888743398
#  OT_PHYSN_NPI                   | NULL
#  NCH_BENE_BLOOD_DDCTBL_LBLTY_AM | 0.00
#  ICD9_DGNS_CD_1                 | 185
#  ICD9_DGNS_CD_2                 | NULL
#  ICD9_DGNS_CD_3                 | NULL
#  ICD9_DGNS_CD_4                 | NULL
#  ICD9_DGNS_CD_5                 | NULL
#  ICD9_DGNS_CD_6                 | NULL
#  ICD9_DGNS_CD_7                 | NULL
#  ICD9_DGNS_CD_8                 | NULL
#  ICD9_DGNS_CD_9                 | NULL
#  ICD9_DGNS_CD_10                | NULL
#  ICD9_PRCDR_CD_1                | NULL
#  ICD9_PRCDR_CD_2                | NULL
#  ICD9_PRCDR_CD_3                | NULL
#  ICD9_PRCDR_CD_4                | NULL
#  ICD9_PRCDR_CD_5                | NULL
#  ICD9_PRCDR_CD_6                | NULL
#  NCH_BENE_PTB_DDCTBL_AMT        | 0.00
#  NCH_BENE_PTB_COINSRNC_AMT      | 0.00
#  ADMTNG_ICD9_DGNS_CD            | NULL
#  HCPCS_CD_1                     | 80053
#  HCPCS_CD_2                     | NULL
#  HCPCS_CD_3                     | NULL
#  HCPCS_CD_4                     | NULL
#  HCPCS_CD_5                     | NULL
#  HCPCS_CD_6                     | NULL
#  HCPCS_CD_7                     | NULL
#  HCPCS_CD_8                     | NULL
#  HCPCS_CD_9                     | NULL
#  HCPCS_CD_10                    | NULL
#  HCPCS_CD_11                    | NULL
#  HCPCS_CD_12                    | NULL
#  HCPCS_CD_13                    | NULL
#  HCPCS_CD_14                    | NULL
#  HCPCS_CD_15                    | NULL
#  HCPCS_CD_16                    | NULL
#  HCPCS_CD_17                    | NULL
#  HCPCS_CD_18                    | NULL
#  HCPCS_CD_19                    | NULL
#  HCPCS_CD_20                    | NULL
#  HCPCS_CD_21                    | NULL
#  HCPCS_CD_22                    | NULL
#  HCPCS_CD_23                    | NULL
#  HCPCS_CD_24                    | NULL
#  HCPCS_CD_25                    | NULL
#  HCPCS_CD_26                    | NULL
#  HCPCS_CD_27                    | NULL
#  HCPCS_CD_28                    | NULL
#  HCPCS_CD_29                    | NULL
#  HCPCS_CD_30                    | NULL
#  HCPCS_CD_31                    | NULL
#  HCPCS_CD_32                    | NULL
#  HCPCS_CD_33                    | NULL
#  HCPCS_CD_34                    | NULL
#  HCPCS_CD_35                    | NULL
#  HCPCS_CD_36                    | NULL
#  HCPCS_CD_37                    | NULL
#  HCPCS_CD_38                    | NULL
#  HCPCS_CD_39                    | NULL
#  HCPCS_CD_40                    | NULL
#  HCPCS_CD_41                    | NULL
#  HCPCS_CD_42                    | NULL
#  HCPCS_CD_43                    | NULL
#  HCPCS_CD_44                    | NULL
#  HCPCS_CD_45                    | NULL
# -RECORD 2------------------------------------------
#  DESYNPUF_ID                    | 00028CFDA8612B87
#  BENE_BIRTH_DT                  | 19431001
#  BENE_DEATH_DT                  | NULL
#  BENE_SEX_IDENT_CD              | 2
#  BENE_RACE_CD                   | 1
#  BENE_ESRD_IND                  | 0
#  SP_STATE_CODE                  | 14
#  BENE_COUNTY_CD                 | 740
#  BENE_HI_CVRAGE_TOT_MONS        | 12
#  BENE_SMI_CVRAGE_TOT_MONS       | 12
#  BENE_HMO_CVRAGE_TOT_MONS       | 0
#  PLAN_CVRG_MOS_NUM              | 00
#  SP_ALZHDMTA                    | 0
#  SP_CHF                         | 0
#  SP_CHRNKIDN                    | 0
#  SP_CNCR                        | 0
#  SP_COPD                        | 0
#  SP_DEPRESSN                    | 1
#  SP_DIABETES                    | 1
#  SP_ISCHMCHT                    | 1
#  SP_OSTEOPRS                    | 0
#  SP_RA_OA                       | 0
#  SP_STRKETIA                    | 0
#  MEDREIMB_IP                    | 0.00
#  BENRES_IP                      | 0.00
#  PPPYMT_IP                      | 0.00
#  MEDREIMB_OP                    | 1300.00
#  BENRES_OP                      | 110.00
#  PPPYMT_OP                      | 0.00
#  MEDREIMB_CAR                   | 1600.00
#  BENRES_CAR                     | 410.00
#  PPPYMT_CAR                     | 0.00
#  Conditions_Total               | Multiple
#  CLM_ID                         | 684612269927362
#  SEGMENT                        | 1
#  CLM_FROM_DT                    | 20090911
#  CLM_THRU_DT                    | 20090926
#  PRVDR_NUM                      | 1402GT
#  CLM_PMT_AMT                    | 400.00
#  NCH_PRMRY_PYR_CLM_PD_AMT       | 0.00
#  AT_PHYSN_NPI                   | 6644238189
#  OP_PHYSN_NPI                   | NULL
#  OT_PHYSN_NPI                   | NULL
#  NCH_BENE_BLOOD_DDCTBL_LBLTY_AM | 0.00
#  ICD9_DGNS_CD_1                 | 72665
#  ICD9_DGNS_CD_2                 | NULL
#  ICD9_DGNS_CD_3                 | NULL
#  ICD9_DGNS_CD_4                 | NULL
#  ICD9_DGNS_CD_5                 | NULL
#  ICD9_DGNS_CD_6                 | NULL
#  ICD9_DGNS_CD_7                 | NULL
#  ICD9_DGNS_CD_8                 | NULL
#  ICD9_DGNS_CD_9                 | NULL
#  ICD9_DGNS_CD_10                | NULL
#  ICD9_PRCDR_CD_1                | NULL
#  ICD9_PRCDR_CD_2                | NULL
#  ICD9_PRCDR_CD_3                | NULL
#  ICD9_PRCDR_CD_4                | NULL
#  ICD9_PRCDR_CD_5                | NULL
#  ICD9_PRCDR_CD_6                | NULL
#  NCH_BENE_PTB_DDCTBL_AMT        | 0.00
#  NCH_BENE_PTB_COINSRNC_AMT      | 0.00
#  ADMTNG_ICD9_DGNS_CD            | V4365
#  HCPCS_CD_1                     | 97110
#  HCPCS_CD_2                     | 97530
#  HCPCS_CD_3                     | G0283
#  HCPCS_CD_4                     | 97110
#  HCPCS_CD_5                     | 97150
#  HCPCS_CD_6                     | 97112
#  HCPCS_CD_7                     | 97150
#  HCPCS_CD_8                     | 97530
#  HCPCS_CD_9                     | 97140
#  HCPCS_CD_10                    | 97001
#  HCPCS_CD_11                    | G0283
#  HCPCS_CD_12                    | 97110
#  HCPCS_CD_13                    | 97035
#  HCPCS_CD_14                    | NULL
#  HCPCS_CD_15                    | NULL
#  HCPCS_CD_16                    | NULL
#  HCPCS_CD_17                    | NULL
#  HCPCS_CD_18                    | NULL
#  HCPCS_CD_19                    | NULL
#  HCPCS_CD_20                    | NULL
#  HCPCS_CD_21                    | NULL
#  HCPCS_CD_22                    | NULL
#  HCPCS_CD_23                    | NULL
#  HCPCS_CD_24                    | NULL
#  HCPCS_CD_25                    | NULL
#  HCPCS_CD_26                    | NULL
#  HCPCS_CD_27                    | NULL
#  HCPCS_CD_28                    | NULL
#  HCPCS_CD_29                    | NULL
#  HCPCS_CD_30                    | NULL
#  HCPCS_CD_31                    | NULL
#  HCPCS_CD_32                    | NULL
#  HCPCS_CD_33                    | NULL
#  HCPCS_CD_34                    | NULL
#  HCPCS_CD_35                    | NULL
#  HCPCS_CD_36                    | NULL
#  HCPCS_CD_37                    | NULL
#  HCPCS_CD_38                    | NULL
#  HCPCS_CD_39                    | NULL
#  HCPCS_CD_40                    | NULL
#  HCPCS_CD_41                    | NULL
#  HCPCS_CD_42                    | NULL
#  HCPCS_CD_43                    | NULL
#  HCPCS_CD_44                    | NULL
#  HCPCS_CD_45                    | NULL
# -RECORD 3------------------------------------------
#  DESYNPUF_ID                    | 00028CFDA8612B87
#  BENE_BIRTH_DT                  | 19431001
#  BENE_DEATH_DT                  | NULL
#  BENE_SEX_IDENT_CD              | 2
#  BENE_RACE_CD                   | 1
#  BENE_ESRD_IND                  | 0
#  SP_STATE_CODE                  | 14
#  BENE_COUNTY_CD                 | 740
#  BENE_HI_CVRAGE_TOT_MONS        | 12
#  BENE_SMI_CVRAGE_TOT_MONS       | 12
#  BENE_HMO_CVRAGE_TOT_MONS       | 0
#  PLAN_CVRG_MOS_NUM              | 00
#  SP_ALZHDMTA                    | 0
#  SP_CHF                         | 0
#  SP_CHRNKIDN                    | 0
#  SP_CNCR                        | 0
#  SP_COPD                        | 0
#  SP_DEPRESSN                    | 1
#  SP_DIABETES                    | 1
#  SP_ISCHMCHT                    | 1
#  SP_OSTEOPRS                    | 0
#  SP_RA_OA                       | 0
#  SP_STRKETIA                    | 0
#  MEDREIMB_IP                    | 0.00
#  BENRES_IP                      | 0.00
#  PPPYMT_IP                      | 0.00
#  MEDREIMB_OP                    | 1300.00
#  BENRES_OP                      | 110.00
#  PPPYMT_OP                      | 0.00
#  MEDREIMB_CAR                   | 1600.00
#  BENRES_CAR                     | 410.00
#  PPPYMT_CAR                     | 0.00
#  Conditions_Total               | Multiple
#  CLM_ID                         | 684032269922700
#  SEGMENT                        | 1
#  CLM_FROM_DT                    | 20091023
#  CLM_THRU_DT                    | 20091023
#  PRVDR_NUM                      | 1600ZV
#  CLM_PMT_AMT                    | 300.00
#  NCH_PRMRY_PYR_CLM_PD_AMT       | 0.00
#  AT_PHYSN_NPI                   | 7583143728
#  OP_PHYSN_NPI                   | 3546157294
#  OT_PHYSN_NPI                   | 2212764771
#  NCH_BENE_BLOOD_DDCTBL_LBLTY_AM | 0.00
#  ICD9_DGNS_CD_1                 | 4566
#  ICD9_DGNS_CD_2                 | 78096
#  ICD9_DGNS_CD_3                 | 25060
#  ICD9_DGNS_CD_4                 | NULL
#  ICD9_DGNS_CD_5                 | NULL
#  ICD9_DGNS_CD_6                 | NULL
#  ICD9_DGNS_CD_7                 | NULL
#  ICD9_DGNS_CD_8                 | NULL
#  ICD9_DGNS_CD_9                 | NULL
#  ICD9_DGNS_CD_10                | NULL
#  ICD9_PRCDR_CD_1                | NULL
#  ICD9_PRCDR_CD_2                | NULL
#  ICD9_PRCDR_CD_3                | NULL
#  ICD9_PRCDR_CD_4                | NULL
#  ICD9_PRCDR_CD_5                | NULL
#  ICD9_PRCDR_CD_6                | NULL
#  NCH_BENE_PTB_DDCTBL_AMT        | 0.00
#  NCH_BENE_PTB_COINSRNC_AMT      | 10.00
#  ADMTNG_ICD9_DGNS_CD            | NULL
#  HCPCS_CD_1                     | 99214
#  HCPCS_CD_2                     | 83036
#  HCPCS_CD_3                     | NULL
#  HCPCS_CD_4                     | NULL
#  HCPCS_CD_5                     | NULL
#  HCPCS_CD_6                     | NULL
#  HCPCS_CD_7                     | NULL
#  HCPCS_CD_8                     | NULL
#  HCPCS_CD_9                     | NULL
#  HCPCS_CD_10                    | NULL
#  HCPCS_CD_11                    | NULL
#  HCPCS_CD_12                    | NULL
#  HCPCS_CD_13                    | NULL
#  HCPCS_CD_14                    | NULL
#  HCPCS_CD_15                    | NULL
#  HCPCS_CD_16                    | NULL
#  HCPCS_CD_17                    | NULL
#  HCPCS_CD_18                    | NULL
#  HCPCS_CD_19                    | NULL
#  HCPCS_CD_20                    | NULL
#  HCPCS_CD_21                    | NULL
#  HCPCS_CD_22                    | NULL
#  HCPCS_CD_23                    | NULL
#  HCPCS_CD_24                    | NULL
#  HCPCS_CD_25                    | NULL
#  HCPCS_CD_26                    | NULL
#  HCPCS_CD_27                    | NULL
#  HCPCS_CD_28                    | NULL
#  HCPCS_CD_29                    | NULL
#  HCPCS_CD_30                    | NULL
#  HCPCS_CD_31                    | NULL
#  HCPCS_CD_32                    | NULL
#  HCPCS_CD_33                    | NULL
#  HCPCS_CD_34                    | NULL
#  HCPCS_CD_35                    | NULL
#  HCPCS_CD_36                    | NULL
#  HCPCS_CD_37                    | NULL
#  HCPCS_CD_38                    | NULL
#  HCPCS_CD_39                    | NULL
#  HCPCS_CD_40                    | NULL
#  HCPCS_CD_41                    | NULL
#  HCPCS_CD_42                    | NULL
#  HCPCS_CD_43                    | NULL
#  HCPCS_CD_44                    | NULL
#  HCPCS_CD_45                    | NULL
# -RECORD 4------------------------------------------
#  DESYNPUF_ID                    | 00084778C234B1D6
#  BENE_BIRTH_DT                  | 19500901
#  BENE_DEATH_DT                  | NULL
#  BENE_SEX_IDENT_CD              | 2
#  BENE_RACE_CD                   | 1
#  BENE_ESRD_IND                  | 0
#  SP_STATE_CODE                  | 39
#  BENE_COUNTY_CD                 | 010
#  BENE_HI_CVRAGE_TOT_MONS        | 12
#  BENE_SMI_CVRAGE_TOT_MONS       | 12
#  BENE_HMO_CVRAGE_TOT_MONS       | 0
#  PLAN_CVRG_MOS_NUM              | 12
#  SP_ALZHDMTA                    | 1
#  SP_CHF                         | 1
#  SP_CHRNKIDN                    | 0
#  SP_CNCR                        | 0
#  SP_COPD                        | 0
#  SP_DEPRESSN                    | 1
#  SP_DIABETES                    | 1
#  SP_ISCHMCHT                    | 1
#  SP_OSTEOPRS                    | 1
#  SP_RA_OA                       | 0
#  SP_STRKETIA                    | 0
#  MEDREIMB_IP                    | 0.00
#  BENRES_IP                      | 0.00
#  PPPYMT_IP                      | 0.00
#  MEDREIMB_OP                    | 0.00
#  BENRES_OP                      | 0.00
#  PPPYMT_OP                      | 0.00
#  MEDREIMB_CAR                   | 2770.00
#  BENRES_CAR                     | 610.00
#  PPPYMT_CAR                     | 0.00
#  Conditions_Total               | Multiple
#  CLM_ID                         | 684042269661188
#  SEGMENT                        | 1
#  CLM_FROM_DT                    | 20080509
#  CLM_THRU_DT                    | 20080509
#  PRVDR_NUM                      | 3900XQ
#  CLM_PMT_AMT                    | 300.00
#  NCH_PRMRY_PYR_CLM_PD_AMT       | 0.00
#  AT_PHYSN_NPI                   | 4551941274
#  OP_PHYSN_NPI                   | NULL
#  OT_PHYSN_NPI                   | NULL
#  NCH_BENE_BLOOD_DDCTBL_LBLTY_AM | 0.00
#  ICD9_DGNS_CD_1                 | 9139
#  ICD9_DGNS_CD_2                 | 3181
#  ICD9_DGNS_CD_3                 | 41400
#  ICD9_DGNS_CD_4                 | NULL
#  ICD9_DGNS_CD_5                 | NULL
#  ICD9_DGNS_CD_6                 | NULL
#  ICD9_DGNS_CD_7                 | NULL
#  ICD9_DGNS_CD_8                 | NULL
#  ICD9_DGNS_CD_9                 | NULL
#  ICD9_DGNS_CD_10                | NULL
#  ICD9_PRCDR_CD_1                | NULL
#  ICD9_PRCDR_CD_2                | NULL
#  ICD9_PRCDR_CD_3                | NULL
#  ICD9_PRCDR_CD_4                | NULL
#  ICD9_PRCDR_CD_5                | NULL
#  ICD9_PRCDR_CD_6                | NULL
#  NCH_BENE_PTB_DDCTBL_AMT        | 0.00
#  NCH_BENE_PTB_COINSRNC_AMT      | 90.00
#  ADMTNG_ICD9_DGNS_CD            | V714
#  HCPCS_CD_1                     | 70150
#  HCPCS_CD_2                     | 99283
#  HCPCS_CD_3                     | NULL
#  HCPCS_CD_4                     | NULL
#  HCPCS_CD_5                     | NULL
#  HCPCS_CD_6                     | NULL
#  HCPCS_CD_7                     | NULL
#  HCPCS_CD_8                     | NULL
#  HCPCS_CD_9                     | NULL
#  HCPCS_CD_10                    | NULL
#  HCPCS_CD_11                    | NULL
#  HCPCS_CD_12                    | NULL
#  HCPCS_CD_13                    | NULL
#  HCPCS_CD_14                    | NULL
#  HCPCS_CD_15                    | NULL
#  HCPCS_CD_16                    | NULL
#  HCPCS_CD_17                    | NULL
#  HCPCS_CD_18                    | NULL
#  HCPCS_CD_19                    | NULL
#  HCPCS_CD_20                    | NULL
#  HCPCS_CD_21                    | NULL
#  HCPCS_CD_22                    | NULL
#  HCPCS_CD_23                    | NULL
#  HCPCS_CD_24                    | NULL
#  HCPCS_CD_25                    | NULL
#  HCPCS_CD_26                    | NULL
#  HCPCS_CD_27                    | NULL
#  HCPCS_CD_28                    | NULL
#  HCPCS_CD_29                    | NULL
#  HCPCS_CD_30                    | NULL
#  HCPCS_CD_31                    | NULL
#  HCPCS_CD_32                    | NULL
#  HCPCS_CD_33                    | NULL
#  HCPCS_CD_34                    | NULL
#  HCPCS_CD_35                    | NULL
#  HCPCS_CD_36                    | NULL
#  HCPCS_CD_37                    | NULL
#  HCPCS_CD_38                    | NULL
#  HCPCS_CD_39                    | NULL
#  HCPCS_CD_40                    | NULL
#  HCPCS_CD_41                    | NULL
#  HCPCS_CD_42                    | NULL
#  HCPCS_CD_43                    | NULL
#  HCPCS_CD_44                    | NULL
#  HCPCS_CD_45                    | NULL
# only showing top 5 rows

# %%
# What is the distribution of races

# %%
df = joined.withColumn("BENE_RACE_CD", F.when(F.col("BENE_RACE_CD") == "1", "White").otherwise(F.col("BENE_RACE_CD")))
df = df.withColumn("BENE_RACE_CD", F.when(F.col("BENE_RACE_CD") == "2", "Black").otherwise(F.col("BENE_RACE_CD")))
df = df.withColumn("BENE_RACE_CD", F.when(F.col("BENE_RACE_CD") == "3", "Others").otherwise(F.col("BENE_RACE_CD")))
df = df.withColumn("BENE_RACE_CD", F.when(F.col("BENE_RACE_CD") == "5", "Hispanic").otherwise(F.col("BENE_RACE_CD")))

# %%
df.select("BENE_RACE_CD").groupBy("BENE_RACE_CD").count().orderBy("count", ascending=False).show()
# Out:
# +------------+------+
# |BENE_RACE_CD| count|
# +------------+------+
# |       White|688357|
# |       Black| 81907|
# |      Others| 29811|
# |    Hispanic| 18017|
# |        NULL|  1995|
# +------------+------+

# %%
# What is the most common chronic illness combination

# %%
df3b = df.select("DESYNPUF_ID", *diagnoses_cols)

# %%
df3b = df3b.withColumn("SP_ALZHDMTA", F.when(F.col("SP_ALZHDMTA") == "1", "Alzheimer").otherwise(None))
df3b = df3b.withColumn("SP_CHF", F.when(F.col("SP_CHF") == "1", "Heart Failure").otherwise(None))
df3b = df3b.withColumn("SP_CHRNKIDN", F.when(F.col("SP_CHRNKIDN") == "1", "Chronic Kidney Disease").otherwise(None))
df3b = df3b.withColumn("SP_CNCR", F.when(F.col("SP_CNCR") == "1", "Cancer").otherwise(None))
df3b = df3b.withColumn("SP_COPD", F.when(F.col("SP_COPD") == "1", "COPD").otherwise(None))
df3b = df3b.withColumn("SP_DEPRESSN", F.when(F.col("SP_DEPRESSN") == "1", "Depression").otherwise(None))
df3b = df3b.withColumn("SP_DIABETES", F.when(F.col("SP_DIABETES") == "1", "Diabetes").otherwise(None))
df3b = df3b.withColumn("SP_ISCHMCHT", F.when(F.col("SP_ISCHMCHT") == "1", "Ischemic Heart Disease").otherwise(None))
df3b = df3b.withColumn("SP_OSTEOPRS", F.when(F.col("SP_OSTEOPRS") == "1", "Osteoporosis").otherwise(None))
df3b = df3b.withColumn("SP_RA_OA", F.when(F.col("SP_RA_OA") == "1", "RA/OA").otherwise(None))
df3b = df3b.withColumn("SP_STRKETIA", F.when(F.col("SP_STRKETIA") == "1", "Stroke").otherwise(None))
df3b = df3b.distinct()

# %%
result = df3b \
          .withColumn("temp", F.array(*diagnoses_cols)) \
            .withColumn("Illness_List", F.expr("FILTER(temp, x -> x is not null)")) \
                .drop("temp")

# %%
df3b = result.select("DESYNPUF_ID", "Illness_List").distinct()

# %%
df3b.select("Illness_List").groupBy("Illness_List").count().orderBy("count", ascending=False).show(10, truncate=False)
# Out:
# +-------------------------------------------------+-----+
# |Illness_List                                     |count|
# +-------------------------------------------------+-----+
# |[]                                               |37545|
# |[Ischemic Heart Disease]                         |4167 |
# |[Diabetes, Ischemic Heart Disease]               |2043 |
# |[Diabetes]                                       |1928 |
# |[Heart Failure]                                  |1490 |
# |[Depression]                                     |1485 |
# |[Heart Failure, Ischemic Heart Disease]          |1469 |
# |[Heart Failure, Diabetes, Ischemic Heart Disease]|1417 |
# |[Osteoporosis]                                   |1163 |
# |[Alzheimer]                                      |1159 |
# +-------------------------------------------------+-----+
# only showing top 10 rows

# %%
rejoined = df.join(df3b, "DESYNPUF_ID", "left")
rejoined = rejoined.distinct()

# %%
# Which chronic illness combo has highest total cost

# %%
cost_cols = ["MEDREIMB_IP", "BENRES_IP", "PPPYMT_IP", "MEDREIMB_OP", "BENRES_OP", "PPPYMT_OP", "MEDREIMB_CAR", "BENRES_CAR", "PPPYMT_CAR"]

# %%
df3c = rejoined.select("DESYNPUF_ID", *cost_cols, "Illness_List").distinct()

# %%
df3c = df3c.withColumn('Total_Cost', F.expr('+'.join(cost_cols)))

# %%
df3c.groupBy("Illness_List").agg(F.sum("Total_Cost")).orderBy("sum(Total_Cost)", ascending=False).show(10, truncate=False)
# Out:
# +---------------------------------------------------------------------------------------------------------------------------+---------------+
# |Illness_List                                                                                                               |sum(Total_Cost)|
# +---------------------------------------------------------------------------------------------------------------------------+---------------+
# |[]                                                                                                                         |1.298727E7     |
# |[Ischemic Heart Disease]                                                                                                   |9047010.0      |
# |[Alzheimer, Heart Failure, Chronic Kidney Disease, COPD, Depression, Diabetes, Ischemic Heart Disease]                     |9037316.0      |
# |[Heart Failure, Chronic Kidney Disease, Diabetes, Ischemic Heart Disease]                                                  |8757578.0      |
# |[Diabetes, Ischemic Heart Disease]                                                                                         |7503100.0      |
# |[Heart Failure, Diabetes, Ischemic Heart Disease]                                                                          |7011770.0      |
# |[Alzheimer, Heart Failure, Chronic Kidney Disease, COPD, Depression, Diabetes, Ischemic Heart Disease, RA/OA]              |6939902.0      |
# |[Alzheimer, Heart Failure, Chronic Kidney Disease, COPD, Depression, Diabetes, Ischemic Heart Disease, Osteoporosis, RA/OA]|6747780.0      |
# |[Alzheimer, Heart Failure, Chronic Kidney Disease, COPD, Diabetes, Ischemic Heart Disease]                                 |6267766.0      |
# |[Alzheimer, Heart Failure, Chronic Kidney Disease, Depression, Diabetes, Ischemic Heart Disease]                           |6118730.0      |
# +---------------------------------------------------------------------------------------------------------------------------+---------------+
# only showing top 10 rows

# %%
# Which chronic illness combo has highest cost per member

# %%
df3d = df3c.select("DESYNPUF_ID", "Illness_List", "Total_Cost")

# %%
w = Window.partitionBy("Illness_List")
df3d = df3d.withColumn("Total_Cost_Sum", F.sum("Total_Cost").over(w))

# %%
df3d = df3d.withColumn("Illness_Count", F.count("Illness_List").over(w))

# %%
df3d.groupby("Illness_List", "Total_Cost_Sum", "Illness_Count") \
    .agg((F.col("Total_Cost_Sum") / F.col("Illness_Count")).alias("Cost_Per_Mem")) \
        .orderBy("Cost_Per_Mem", ascending=False).show(20, truncate=False, vertical=True)
# Out:
# -RECORD 0-----------------------------------------------------------------------------------------------------------------------------------------------------
#  Illness_List   | [Chronic Kidney Disease, Cancer, COPD, Ischemic Heart Disease, Osteoporosis]
#  Total_Cost_Sum | 85524.0
#  Illness_Count  | 1
#  Cost_Per_Mem   | 85524.0
# -RECORD 1-----------------------------------------------------------------------------------------------------------------------------------------------------
#  Illness_List   | [Alzheimer, Chronic Kidney Disease, Cancer, COPD, Ischemic Heart Disease]
#  Total_Cost_Sum | 79088.0
#  Illness_Count  | 1
#  Cost_Per_Mem   | 79088.0
# -RECORD 2-----------------------------------------------------------------------------------------------------------------------------------------------------
#  Illness_List   | [Alzheimer, Cancer, COPD, Depression, Diabetes, Ischemic Heart Disease, Osteoporosis, RA/OA, Stroke]
#  Total_Cost_Sum | 72812.0
#  Illness_Count  | 1
#  Cost_Per_Mem   | 72812.0
# -RECORD 3-----------------------------------------------------------------------------------------------------------------------------------------------------
#  Illness_List   | [Heart Failure, Chronic Kidney Disease, Cancer, Ischemic Heart Disease, RA/OA, Stroke]
#  Total_Cost_Sum | 62328.0
#  Illness_Count  | 1
#  Cost_Per_Mem   | 62328.0
# -RECORD 4-----------------------------------------------------------------------------------------------------------------------------------------------------
#  Illness_List   | [Heart Failure, Chronic Kidney Disease, COPD, Osteoporosis, Stroke]
#  Total_Cost_Sum | 60558.0
#  Illness_Count  | 1
#  Cost_Per_Mem   | 60558.0
# -RECORD 5-----------------------------------------------------------------------------------------------------------------------------------------------------
#  Illness_List   | [Cancer, Depression, Diabetes, Ischemic Heart Disease, Osteoporosis, RA/OA, Stroke]
#  Total_Cost_Sum | 56908.0
#  Illness_Count  | 1
#  Cost_Per_Mem   | 56908.0
# -RECORD 6-----------------------------------------------------------------------------------------------------------------------------------------------------
#  Illness_List   | [Chronic Kidney Disease, Cancer, COPD, Ischemic Heart Disease, Osteoporosis, RA/OA]
#  Total_Cost_Sum | 44844.0
#  Illness_Count  | 1
#  Cost_Per_Mem   | 44844.0
# -RECORD 7-----------------------------------------------------------------------------------------------------------------------------------------------------
#  Illness_List   | [Alzheimer, Heart Failure, Chronic Kidney Disease, COPD, Depression, Osteoporosis, Stroke]
#  Total_Cost_Sum | 44326.0
#  Illness_Count  | 1
#  Cost_Per_Mem   | 44326.0
# -RECORD 8-----------------------------------------------------------------------------------------------------------------------------------------------------
#  Illness_List   | [Chronic Kidney Disease, COPD, Diabetes, Ischemic Heart Disease, Osteoporosis, RA/OA, Stroke]
#  Total_Cost_Sum | 84552.0
#  Illness_Count  | 2
#  Cost_Per_Mem   | 42276.0
# -RECORD 9-----------------------------------------------------------------------------------------------------------------------------------------------------
#  Illness_List   | [Chronic Kidney Disease, Depression, Ischemic Heart Disease, RA/OA, Stroke]
#  Total_Cost_Sum | 82736.0
#  Illness_Count  | 2
#  Cost_Per_Mem   | 41368.0
# -RECORD 10----------------------------------------------------------------------------------------------------------------------------------------------------
#  Illness_List   | [Heart Failure, Chronic Kidney Disease, Cancer, COPD, Depression, Ischemic Heart Disease, Osteoporosis, RA/OA]
#  Total_Cost_Sum | 79638.0
#  Illness_Count  | 2
#  Cost_Per_Mem   | 39819.0
# -RECORD 11----------------------------------------------------------------------------------------------------------------------------------------------------
#  Illness_List   | [Alzheimer, Chronic Kidney Disease, COPD, Depression, Ischemic Heart Disease, Osteoporosis, RA/OA]
#  Total_Cost_Sum | 39048.0
#  Illness_Count  | 1
#  Cost_Per_Mem   | 39048.0
# -RECORD 12----------------------------------------------------------------------------------------------------------------------------------------------------
#  Illness_List   | [Alzheimer, Heart Failure, Chronic Kidney Disease, COPD, Diabetes, Osteoporosis, Stroke]
#  Total_Cost_Sum | 154260.0
#  Illness_Count  | 4
#  Cost_Per_Mem   | 38565.0
# -RECORD 13----------------------------------------------------------------------------------------------------------------------------------------------------
#  Illness_List   | [Alzheimer, Heart Failure, Chronic Kidney Disease, Cancer, COPD, Depression, Diabetes, Ischemic Heart Disease, Osteoporosis, RA/OA, Stroke]
#  Total_Cost_Sum | 1268834.0
#  Illness_Count  | 33
#  Cost_Per_Mem   | 38449.51515151515
# -RECORD 14----------------------------------------------------------------------------------------------------------------------------------------------------
#  Illness_List   | [Alzheimer, Heart Failure, Chronic Kidney Disease, Cancer, COPD, Diabetes, Ischemic Heart Disease, Osteoporosis, Stroke]
#  Total_Cost_Sum | 344770.0
#  Illness_Count  | 9
#  Cost_Per_Mem   | 38307.77777777778
# -RECORD 15----------------------------------------------------------------------------------------------------------------------------------------------------
#  Illness_List   | [Alzheimer, Cancer, COPD, Ischemic Heart Disease, Osteoporosis, RA/OA]
#  Total_Cost_Sum | 37236.0
#  Illness_Count  | 1
#  Cost_Per_Mem   | 37236.0
# -RECORD 16----------------------------------------------------------------------------------------------------------------------------------------------------
#  Illness_List   | [Alzheimer, Heart Failure, Chronic Kidney Disease, COPD, Osteoporosis]
#  Total_Cost_Sum | 37058.0
#  Illness_Count  | 1
#  Cost_Per_Mem   | 37058.0
# -RECORD 17----------------------------------------------------------------------------------------------------------------------------------------------------
#  Illness_List   | [Alzheimer, Heart Failure, Chronic Kidney Disease, RA/OA, Stroke]
#  Total_Cost_Sum | 73548.0
#  Illness_Count  | 2
#  Cost_Per_Mem   | 36774.0
# -RECORD 18----------------------------------------------------------------------------------------------------------------------------------------------------
#  Illness_List   | [Alzheimer, Cancer, COPD, Depression, Ischemic Heart Disease, Stroke]
#  Total_Cost_Sum | 36188.0
#  Illness_Count  | 1
#  Cost_Per_Mem   | 36188.0
# -RECORD 19----------------------------------------------------------------------------------------------------------------------------------------------------
#  Illness_List   | [Alzheimer, Chronic Kidney Disease, Cancer, Depression, Diabetes, Ischemic Heart Disease, Osteoporosis, RA/OA, Stroke]
#  Total_Cost_Sum | 72266.0
#  Illness_Count  | 2
#  Cost_Per_Mem   | 36133.0
# only showing top 20 rows

# %%
spark.stop()
